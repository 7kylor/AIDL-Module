# %%
#  week 2 exercises  

import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
 
df = pd.read_csv('./FuelConsumption.csv')
df.head(5) 
df.tail(5)
print(df.shape)
print(df.dtypes)
 
 
df.plot(x='MODELYEAR', y='CO2EMISSIONS' , style="+")
df.plot(x='FUELCONSUMPTION_CITY', y='CO2EMISSIONS', kind='scatter')
# Out:
# (1067, 13)
# MODELYEAR                     int64
# MAKE                         object
# MODEL                        object
# VEHICLECLASS                 object
# ENGINESIZE                  float64
# CYLINDERS                     int64
# TRANSMISSION                 object
# FUELTYPE                     object
# FUELCONSUMPTION_CITY        float64
# FUELCONSUMPTION_HWY         float64
# FUELCONSUMPTION_COMB        float64
# FUELCONSUMPTION_COMB_MPG      int64
# CO2EMISSIONS                  int64
# dtype: object
# <Axes: xlabel='FUELCONSUMPTION_CITY', ylabel='CO2EMISSIONS'>
